# %%
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the requests library.
import requests

# Import the API key.
from config import api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | hobart
# Processing Record 2 of Set 15 | nanortalik
# Processing Record 3 of Set 15 | cape town
# Processing Record 4 of Set 15 | champerico
# Processing Record 5 of Set 15 | inirida
# Processing Record 6 of Set 15 | villarrica
# Processing Record 7 of Set 15 | oyama
# Processing Record 8 of Set 15 | torbay
# Processing Record 9 of Set 15 | jamestown
# Processing Record 10 of Set 15 | badarwas
# Processing Record 11 of Set 15 | nikolskoye
# Processing Record 12 of Set 15 | berlevag
# Processing Record 13 of Set 15 | hemsedal
# Processing Record 14 of Set 15 | tkvarcheli
# City not found. Skipping...
# Processing Record 15 of Set 15 | norman wells
# Processing Record 16 of Set 15 | carnarvon
# Processing Record 17 of Set 15 | viedma
# Processing Record 18 of Set 15 | kununurra
# Processing Record 19 of Set 15 | mitu
# Processing Record 20 of Set 15 | codrington
# Processing Record 21 of Set 15 | bluff
# Processing Record 22 of Set 15 | guerrero negro
# Processing Record 23 of Set 15 | new norfolk
# Processing Record 24 of Set 15 | chopovychi
# Processing Record 25 of Set 15 | mataura
# Processing Record 26 of Set 15 | rikitea
# Processing Record 27 of Set 15 | brodokalmak
# Processing Record 28 of Set 15 | muskogee
# Processing Record 29 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 15 | yellowknife
# Processing Record 31 of Set 15 | saint george
# Processing Record 32 of Set 15 | chagoda
# Processing Record 33 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 15 | san ramon
# Processing Record 35 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 15 | atuona
# Processing Record 37 of Set 15 | mogadishu
# Processing Record 38 of Set 15 | batesville
# Processing Record 39 of Set 15 | alugan
# Processing Record 40 of Set 15 | puerto ayora
# Processing Record 41 of Set 15 | busselton
# Processing Record 42 of Set 15 | hithadhoo
# Processing Record 43 of Set 15 | hondo
# Processing Record 44 of Set 15 | saint-philippe
# Processing Record 45 of Set 15 | hermanus
# Processing Record 46 of Set 15 | ushuaia
# Processing Record 47 of Set 15 | san patricio
# Processing Record 48 of Set 15 | verkhoyansk
# Processing Record 49 of Set 15 | port elizabeth
# Processing Record 50 of Set 15 | waddan
# Processing Record 1 of Set 16 | dikson
# Processing Record 2 of Set 16 | port alfred
# Processing Record 3 of Set 16 | alakurtti
# Processing Record 4 of Set 16 | mar del plata
# Processing Record 5 of Set 16 | narsaq
# Processing Record 6 of Set 16 | ribeira grande
# Processing Record 7 of Set 16 | paamiut
# Processing Record 8 of Set 16 | kupang
# Processing Record 9 of Set 16 | haverfordwest
# Processing Record 10 of Set 16 | lubango
# Processing Record 11 of Set 16 | thompson
# Processing Record 12 of Set 16 | isangel
# Processing Record 13 of Set 16 | leningradskiy
# Processing Record 14 of Set 16 | mahebourg
# Processing Record 15 of Set 16 | dunedin
# Processing Record 16 of Set 16 | salalah
# Processing Record 17 of Set 16 | biak
# Processing Record 18 of Set 16 | point pedro
# Processing Record 19 of Set 16 | sitka
# Processing Record 20 of Set 16 | kapaa
# Processing Record 21 of Set 16 | bethel
# Processing Record 22 of Set 16 | koroni
# Processing Record 23 of Set 16 | tuatapere
# Processing Record 24 of Set 16 | tacna
# Processing Record 25 of Set 16 | punta arenas
# Processing Record 26 of Set 16 | luanda
# Processing Record 27 of Set 16 | georgetown
# Processing Record 28 of Set 16 | kaitangata
# Processing Record 29 of Set 16 | ormara
# Processing Record 30 of Set 16 | dickinson
# Processing Record 31 of Set 16 | ust-tsilma
# Processing Record 32 of Set 16 | fortuna
# Processing Record 33 of Set 16 | severo-yeniseyskiy
# Processing Record 34 of Set 16 | bulungu
# Processing Record 35 of Set 16 | albany
# Processing Record 36 of Set 16 | manokwari
# Processing Record 37 of Set 16 | santa maria
# Processing Record 38 of Set 16 | almaznyy
# Processing Record 39 of Set 16 | tazovskiy
# Processing Record 40 of Set 16 | gavle
# Processing Record 41 of Set 16 | vaini
# Processing Record 42 of Set 16 | khatanga
# Processing Record 43 of Set 16 | ixtapa
# Processing Record 44 of Set 16 | comarapa
# Processing Record 45 of Set 16 | aklavik
# Processing Record 46 of Set 16 | yudong
# Processing Record 47 of Set 16 | harlingen
# Processing Record 48 of Set 16 | cherskiy
# Processing Record 49 of Set 16 | kjollefjord
# Processing Record 50 of Set 16 | chuy
# Processing Record 1 of Set 17 | qaanaaq
# Processing Record 2 of Set 17 | carutapera
# Processing Record 3 of Set 17 | sao miguel do araguaia
# Processing Record 4 of Set 17 | sibu
# Processing Record 5 of Set 17 | aberdeen
# Processing Record 6 of Set 17 | broome
# Processing Record 7 of Set 17 | portland
# Processing Record 8 of Set 17 | ercis
# Processing Record 9 of Set 17 | san rafael
# Processing Record 10 of Set 17 | bandarbeyla
# Processing Record 11 of Set 17 | cidreira
# Processing Record 12 of Set 17 | mizdah
# Processing Record 13 of Set 17 | barrow
# Processing Record 14 of Set 17 | borogontsy
# Processing Record 15 of Set 17 | vestmanna
# Processing Record 16 of Set 17 | nedjo
# Processing Record 17 of Set 17 | dingle
# Processing Record 18 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 17 | jalu
# Processing Record 20 of Set 17 | coihaique
# Processing Record 21 of Set 17 | bredasdorp
# Processing Record 22 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 17 | bambous virieux
# Processing Record 24 of Set 17 | thinadhoo
# Processing Record 25 of Set 17 | bubaque
# Processing Record 26 of Set 17 | uvira
# Processing Record 27 of Set 17 | souillac
# Processing Record 28 of Set 17 | saskylakh
# Processing Record 29 of Set 17 | port lincoln
# Processing Record 30 of Set 17 | gigmoto
# Processing Record 31 of Set 17 | vila velha
# Processing Record 32 of Set 17 | vila franca do campo
# Processing Record 33 of Set 17 | pingliang
# Processing Record 34 of Set 17 | dzerzhinskoye
# Processing Record 35 of Set 17 | hasaki
# Processing Record 36 of Set 17 | severo-kurilsk
# Processing Record 37 of Set 17 | barabinsk
# Processing Record 38 of Set 17 | faya
# Processing Record 39 of Set 17 | arraial do cabo
# Processing Record 40 of Set 17 | sakakah
# Processing Record 41 of Set 17 | avarua
# Processing Record 42 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 17 | erzin
# Processing Record 44 of Set 17 | vytegra
# Processing Record 45 of Set 17 | praia
# Processing Record 46 of Set 17 | victoria
# Processing Record 47 of Set 17 | bathsheba
# Processing Record 48 of Set 17 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 17 | lebu
# Processing Record 50 of Set 17 | port hardy
# Processing Record 1 of Set 18 | venado tuerto
# Processing Record 2 of Set 18 | sheboygan
# Processing Record 3 of Set 18 | cabo san lucas
# Processing Record 4 of Set 18 | tabou
# Processing Record 5 of Set 18 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 18 | mahibadhoo
# Processing Record 7 of Set 18 | esperance
# Processing Record 8 of Set 18 | buala
# Processing Record 9 of Set 18 | paraiso
# Processing Record 10 of Set 18 | trebisacce
# Processing Record 11 of Set 18 | tonantins
# Processing Record 12 of Set 18 | kavieng
# Processing Record 13 of Set 18 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 18 | belyy yar
# Processing Record 15 of Set 18 | chapais
# Processing Record 16 of Set 18 | kodiak
# Processing Record 17 of Set 18 | havoysund
# Processing Record 18 of Set 18 | bangassou
# Processing Record 19 of Set 18 | ostrovnoy
# Processing Record 20 of Set 18 | port hedland
# Processing Record 21 of Set 18 | bengkulu
# Processing Record 22 of Set 18 | kaputa
# Processing Record 23 of Set 18 | bereda
# Processing Record 24 of Set 18 | saint-augustin
# Processing Record 25 of Set 18 | sao lourenco do sul
# Processing Record 26 of Set 18 | pangoa
# Processing Record 27 of Set 18 | bislig
# Processing Record 28 of Set 18 | damara
# Processing Record 29 of Set 18 | tiznit
# Processing Record 30 of Set 18 | sechura
# Processing Record 31 of Set 18 | milkovo
# Processing Record 32 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 18 | provideniya
# Processing Record 34 of Set 18 | kahului
# Processing Record 35 of Set 18 | tambul
# City not found. Skipping...
# Processing Record 36 of Set 18 | ballina
# Processing Record 37 of Set 18 | aguimes
# Processing Record 38 of Set 18 | butaritari
# Processing Record 39 of Set 18 | ginda
# Processing Record 40 of Set 18 | honiara
# Processing Record 41 of Set 18 | kotido
# Processing Record 42 of Set 18 | tandil
# Processing Record 43 of Set 18 | kandrian
# Processing Record 44 of Set 18 | san julian
# Processing Record 45 of Set 18 | tasiilaq
# Processing Record 46 of Set 18 | mnogovershinnyy
# Processing Record 47 of Set 18 | kieta
# Processing Record 48 of Set 18 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 18 | upernavik
# Processing Record 50 of Set 18 | alofi
# Processing Record 1 of Set 19 | hervey bay
# Processing Record 2 of Set 19 | lagoa
# Processing Record 3 of Set 19 | westport
# Processing Record 4 of Set 19 | antigonish
# Processing Record 5 of Set 19 | chokurdakh
# Processing Record 6 of Set 19 | chernushka
# Processing Record 7 of Set 19 | hilo
# Processing Record 8 of Set 19 | nouadhibou
# Processing Record 9 of Set 19 | naze
# Processing Record 10 of Set 19 | san matias
# Processing Record 11 of Set 19 | egvekinot
# Processing Record 12 of Set 19 | yar-sale
# Processing Record 13 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 19 | saldanha
# Processing Record 15 of Set 19 | lorengau
# Processing Record 16 of Set 19 | galesong
# Processing Record 17 of Set 19 | penzance
# Processing Record 18 of Set 19 | colquechaca
# Processing Record 19 of Set 19 | sorland
# Processing Record 20 of Set 19 | comodoro rivadavia
# Processing Record 21 of Set 19 | namibe
# Processing Record 22 of Set 19 | vardo
# Processing Record 23 of Set 19 | lompoc
# Processing Record 24 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 19 | hofn
# Processing Record 26 of Set 19 | yumen
# Processing Record 27 of Set 19 | palu
# Processing Record 28 of Set 19 | snyder
# Processing Record 29 of Set 19 | saint-michel-des-saints
# Processing Record 30 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 19 | airai
# Processing Record 32 of Set 19 | garowe
# Processing Record 33 of Set 19 | luderitz
# Processing Record 34 of Set 19 | oildale
# Processing Record 35 of Set 19 | bengkalis
# City not found. Skipping...
# Processing Record 36 of Set 19 | dakar
# Processing Record 37 of Set 19 | homer
# Processing Record 38 of Set 19 | puerto maldonado
# Processing Record 39 of Set 19 | tanete
# Processing Record 40 of Set 19 | sao filipe
# Processing Record 41 of Set 19 | praia da vitoria
# Processing Record 42 of Set 19 | auki
# Processing Record 43 of Set 19 | kumphawapi
# Processing Record 44 of Set 19 | pochutla
# Processing Record 45 of Set 19 | panaba
# Processing Record 46 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 19 | doha
# Processing Record 48 of Set 19 | aykhal
# Processing Record 49 of Set 19 | pisco
# Processing Record 50 of Set 19 | nguru
# Processing Record 1 of Set 20 | iqaluit
# Processing Record 2 of Set 20 | sambava
# Processing Record 3 of Set 20 | mayo
# Processing Record 4 of Set 20 | ketchikan
# Processing Record 5 of Set 20 | chingirlau
# Processing Record 6 of Set 20 | sayyan
# Processing Record 7 of Set 20 | ponta do sol
# Processing Record 8 of Set 20 | bara
# Processing Record 9 of Set 20 | lufilufi
# Processing Record 10 of Set 20 | aripuana
# Processing Record 11 of Set 20 | sinnamary
# Processing Record 12 of Set 20 | meiktila
# Processing Record 13 of Set 20 | xuchang
# Processing Record 14 of Set 20 | broken hill
# Processing Record 15 of Set 20 | muzhi
# Processing Record 16 of Set 20 | tiksi
# Processing Record 17 of Set 20 | olafsvik
# Processing Record 18 of Set 20 | east london
# Processing Record 19 of Set 20 | longyearbyen
# Processing Record 20 of Set 20 | mount isa
# Processing Record 21 of Set 20 | port augusta
# Processing Record 22 of Set 20 | lugovoy
# Processing Record 23 of Set 20 | colesberg
# Processing Record 24 of Set 20 | sal rei
# Processing Record 25 of Set 20 | praya
# Processing Record 26 of Set 20 | grenada
# Processing Record 27 of Set 20 | tuktoyaktuk
# Processing Record 28 of Set 20 | gat
# Processing Record 29 of Set 20 | beruwala
# Processing Record 30 of Set 20 | ozernovskiy
# Processing Record 31 of Set 20 | gwanda
# Processing Record 32 of Set 20 | nome
# Processing Record 33 of Set 20 | junin
# Processing Record 34 of Set 20 | sicamous
# Processing Record 35 of Set 20 | regina
# Processing Record 36 of Set 20 | duluth
# Processing Record 37 of Set 20 | illapel
# Processing Record 38 of Set 20 | seguin
# Processing Record 39 of Set 20 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 20 | cockburn town
# Processing Record 41 of Set 20 | boca do acre
# Processing Record 42 of Set 20 | zwedru
# Processing Record 43 of Set 20 | banda aceh
# Processing Record 44 of Set 20 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 20 | mahanoro
# Processing Record 46 of Set 20 | tecoanapa
# Processing Record 47 of Set 20 | genhe
# Processing Record 48 of Set 20 | straumen
# Processing Record 49 of Set 20 | havelock
# Processing Record 50 of Set 20 | lata
# Processing Record 1 of Set 21 | talnakh
# Processing Record 2 of Set 21 | hovd
# Processing Record 3 of Set 21 | goderich
# Processing Record 4 of Set 21 | gouyave
# Processing Record 5 of Set 21 | bardiyah
# Processing Record 6 of Set 21 | moron
# Processing Record 7 of Set 21 | elizabeth city
# Processing Record 8 of Set 21 | gorodets
# Processing Record 9 of Set 21 | riyadh
# Processing Record 10 of Set 21 | ascension
# Processing Record 11 of Set 21 | kimbe
# Processing Record 12 of Set 21 | pangkalanbuun
# Processing Record 13 of Set 21 | marzuq
# Processing Record 14 of Set 21 | kahama
# Processing Record 15 of Set 21 | ilulissat
# Processing Record 16 of Set 21 | yataity
# Processing Record 17 of Set 21 | nelipyno
# Processing Record 18 of Set 21 | oistins
# Processing Record 19 of Set 21 | paracuru
# Processing Record 20 of Set 21 | inhambane
# Processing Record 21 of Set 21 | cherlak
# Processing Record 22 of Set 21 | nykoping
# Processing Record 23 of Set 21 | uberaba
# Processing Record 24 of Set 21 | half moon bay
# Processing Record 25 of Set 21 | skibbereen
# Processing Record 26 of Set 21 | tyrma
# Processing Record 27 of Set 21 | moba
# Processing Record 28 of Set 21 | fukue
# Processing Record 29 of Set 21 | dahuk
# Processing Record 30 of Set 21 | gillette
# Processing Record 31 of Set 21 | ures
# Processing Record 32 of Set 21 | sedelnikovo
# City not found. Skipping...
# Processing Record 33 of Set 21 | issia
# Processing Record 34 of Set 21 | harnai
# Processing Record 35 of Set 21 | buritizeiro
# Processing Record 36 of Set 21 | muros
# Processing Record 37 of Set 21 | san jose
# Processing Record 38 of Set 21 | korla
# Processing Record 39 of Set 21 | rantauprapat
# Processing Record 40 of Set 21 | yulara
# Processing Record 41 of Set 21 | niono
# Processing Record 42 of Set 21 | matadi
# Processing Record 43 of Set 21 | katobu
# Processing Record 44 of Set 21 | fuling
# Processing Record 45 of Set 21 | hit
# Processing Record 46 of Set 21 | maloy
# Processing Record 47 of Set 21 | ulaanbaatar
# Processing Record 48 of Set 21 | tecpan
# Processing Record 49 of Set 21 | chalmette
# Processing Record 50 of Set 21 | baykit
# Processing Record 1 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 22 | komsomolskiy
# Processing Record 3 of Set 22 | danesti
# Processing Record 4 of Set 22 | srednekolymsk
# Processing Record 5 of Set 22 | alice springs
# Processing Record 6 of Set 22 | sept-iles
# Processing Record 7 of Set 22 | azul
# Processing Record 8 of Set 22 | ulladulla
# Processing Record 9 of Set 22 | constitucion
# Processing Record 10 of Set 22 | sento se
# City not found. Skipping...
# Processing Record 11 of Set 22 | lamar
# Processing Record 12 of Set 22 | clonakilty
# Processing Record 13 of Set 22 | monte azul paulista
# Processing Record 14 of Set 22 | vestmannaeyjar
# Processing Record 15 of Set 22 | saiha
# Processing Record 16 of Set 22 | umm kaddadah
# Processing Record 17 of Set 22 | shiraz
# Processing Record 18 of Set 22 | rocha
# Processing Record 19 of Set 22 | hudson bay
# Processing Record 20 of Set 22 | gamba
# Processing Record 21 of Set 22 | englehart
# Processing Record 22 of Set 22 | lichuan
# Processing Record 23 of Set 22 | shaoyang
# Processing Record 24 of Set 22 | dharmavaram
# Processing Record 25 of Set 22 | la plata
# Processing Record 26 of Set 22 | pringsewu
# Processing Record 27 of Set 22 | kulykivka
# Processing Record 28 of Set 22 | sabancuy
# Processing Record 29 of Set 22 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 22 | mount gambier
# Processing Record 31 of Set 22 | sibiti
# Processing Record 32 of Set 22 | babaeski
# Processing Record 33 of Set 22 | harper
# Processing Record 34 of Set 22 | clyde river
# Processing Record 35 of Set 22 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 22 | rawson
# Processing Record 37 of Set 22 | coquimbo
# Processing Record 38 of Set 22 | langsa
# Processing Record 39 of Set 22 | corinth
# Processing Record 40 of Set 22 | prince rupert
# Processing Record 41 of Set 22 | butajira
# Processing Record 42 of Set 22 | bacuit
# City not found. Skipping...
# Processing Record 43 of Set 22 | turbat
# Processing Record 44 of Set 22 | shellbrook
# Processing Record 45 of Set 22 | abha
# Processing Record 46 of Set 22 | acarau
# Processing Record 47 of Set 22 | ofunato
# Processing Record 48 of Set 22 | pevek
# Processing Record 49 of Set 22 | kaniama
# Processing Record 50 of Set 22 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 23 | jacqueville
# Processing Record 2 of Set 23 | vila
# Processing Record 3 of Set 23 | teofilo otoni
# Processing Record 4 of Set 23 | college
# Processing Record 5 of Set 23 | saint-georges
# Processing Record 6 of Set 23 | suileng
# Processing Record 7 of Set 23 | promissao
# Processing Record 8 of Set 23 | lavrentiya
# Processing Record 9 of Set 23 | flinders
# Processing Record 10 of Set 23 | ayagoz
# Processing Record 11 of Set 23 | anchorage
# Processing Record 12 of Set 23 | ahuimanu
# Processing Record 13 of Set 23 | karratha
# Processing Record 14 of Set 23 | burnie
# Processing Record 15 of Set 23 | san andres
# Processing Record 16 of Set 23 | muana
# Processing Record 17 of Set 23 | hualmay
# Processing Record 18 of Set 23 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 23 | puerto escondido
# Processing Record 20 of Set 23 | okhotsk
# Processing Record 21 of Set 23 | tautira
# Processing Record 22 of Set 23 | salta
# Processing Record 23 of Set 23 | axim
# Processing Record 24 of Set 23 | padang
# Processing Record 25 of Set 23 | port blair
# Processing Record 26 of Set 23 | nuuk
# Processing Record 27 of Set 23 | hamilton
# Processing Record 28 of Set 23 | puerto madryn
# Processing Record 29 of Set 23 | tevaitoa
# Processing Record 30 of Set 23 | kawalu
# Processing Record 31 of Set 23 | antalaha
# Processing Record 32 of Set 23 | surt
# Processing Record 33 of Set 23 | bilibino
# Processing Record 34 of Set 23 | castro
# Processing Record 35 of Set 23 | grand gaube
# Processing Record 36 of Set 23 | acapulco
# Processing Record 37 of Set 23 | barice
# Processing Record 38 of Set 23 | kabompo
# Processing Record 39 of Set 23 | labuhan
# Processing Record 40 of Set 23 | hayden
# Processing Record 41 of Set 23 | haines junction
# Processing Record 42 of Set 23 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 23 | regente feijo
# Processing Record 44 of Set 23 | asau
# Processing Record 45 of Set 23 | magan
# Processing Record 46 of Set 23 | kerema
# Processing Record 47 of Set 23 | alekseyevsk
# Processing Record 48 of Set 23 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 23 | tessalit
# Processing Record 50 of Set 23 | yanam
# Processing Record 1 of Set 24 | kruisfontein
# Processing Record 2 of Set 24 | la rioja
# Processing Record 3 of Set 24 | maniwaki
# Processing Record 4 of Set 24 | sao felix do xingu
# Processing Record 5 of Set 24 | lakhipur
# Processing Record 6 of Set 24 | vanimo
# Processing Record 7 of Set 24 | gao
# Processing Record 8 of Set 24 | muravlenko
# Processing Record 9 of Set 24 | riverton
# Processing Record 10 of Set 24 | velyka bahachka
# Processing Record 11 of Set 24 | pahrump
# Processing Record 12 of Set 24 | nehe
# Processing Record 13 of Set 24 | funtua
# Processing Record 14 of Set 24 | saint anthony
# Processing Record 15 of Set 24 | faanui
# Processing Record 16 of Set 24 | needham
# Processing Record 17 of Set 24 | brae
# Processing Record 18 of Set 24 | honningsvag
# Processing Record 19 of Set 24 | arkhangelskoye
# Processing Record 20 of Set 24 | riberalta
# Processing Record 21 of Set 24 | mandalgovi
# Processing Record 22 of Set 24 | zhigansk
# Processing Record 23 of Set 24 | vao
# Processing Record 24 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 24 | kasongo-lunda
# Processing Record 26 of Set 24 | joao pinheiro
# Processing Record 27 of Set 24 | quelimane
# Processing Record 28 of Set 24 | makakilo city
# Processing Record 29 of Set 24 | salo
# Processing Record 30 of Set 24 | liaoyang
# Processing Record 31 of Set 24 | sistranda
# Processing Record 32 of Set 24 | new iberia
# Processing Record 33 of Set 24 | santa vitoria do palmar
# Processing Record 34 of Set 24 | panama city
# Processing Record 35 of Set 24 | savinka
# Processing Record 36 of Set 24 | meulaboh
# Processing Record 37 of Set 24 | krasnoselkup
# Processing Record 38 of Set 24 | coos bay
# Processing Record 39 of Set 24 | grindavik
# Processing Record 40 of Set 24 | kavaratti
# Processing Record 41 of Set 24 | russell
# Processing Record 42 of Set 24 | vilcun
# Processing Record 43 of Set 24 | kushmurun
# Processing Record 44 of Set 24 | port keats
# Processing Record 45 of Set 24 | dargaville
# Processing Record 46 of Set 24 | kautokeino
# Processing Record 47 of Set 24 | kibaya
# Processing Record 48 of Set 24 | svetlogorsk
# Processing Record 49 of Set 24 | caconda
# Processing Record 50 of Set 24 | laguna
# Processing Record 1 of Set 25 | moerai
# Processing Record 2 of Set 25 | palmer
# Processing Record 3 of Set 25 | leshukonskoye
# Processing Record 4 of Set 25 | rincon
# Processing Record 5 of Set 25 | mahina
# Processing Record 6 of Set 25 | kloulklubed
# Processing Record 7 of Set 25 | olinda
# Processing Record 8 of Set 25 | atambua
# Processing Record 9 of Set 25 | chauk
# Processing Record 10 of Set 25 | liverpool
# Processing Record 11 of Set 25 | nhulunbuy
# Processing Record 12 of Set 25 | buta
# Processing Record 13 of Set 25 | lerwick
# Processing Record 14 of Set 25 | leeuwarden
# Processing Record 15 of Set 25 | mirnyy
# Processing Record 16 of Set 25 | ostrov
# Processing Record 17 of Set 25 | fukuma
# Processing Record 18 of Set 25 | cabedelo
# Processing Record 19 of Set 25 | dublin
# Processing Record 20 of Set 25 | ondjiva
# Processing Record 21 of Set 25 | bhongir
# Processing Record 22 of Set 25 | batagay-alyta
# Processing Record 23 of Set 25 | eyl
# Processing Record 24 of Set 25 | sao miguel
# Processing Record 25 of Set 25 | buchanan
# Processing Record 26 of Set 25 | houma
# Processing Record 27 of Set 25 | luau
# Processing Record 28 of Set 25 | miramas
# Processing Record 29 of Set 25 | muisne
# Processing Record 30 of Set 25 | alcazar de san juan
# Processing Record 31 of Set 25 | wawa
# Processing Record 32 of Set 25 | chikwawa
# Processing Record 33 of Set 25 | podporozhye
# Processing Record 34 of Set 25 | prince george
# Processing Record 35 of Set 25 | port macquarie
# Processing Record 36 of Set 25 | mukacheve
# Processing Record 37 of Set 25 | okitipupa
# Processing Record 38 of Set 25 | mount hagen
# Processing Record 39 of Set 25 | luwuk
# Processing Record 40 of Set 25 | pangody
# Processing Record 41 of Set 25 | hay river
# Processing Record 42 of Set 25 | khani
# Processing Record 43 of Set 25 | sao francisco de paula
# Processing Record 44 of Set 25 | chachoengsao
# Processing Record 45 of Set 25 | jubayl
# City not found. Skipping...
# Processing Record 46 of Set 25 | oktyabrskiy
# Processing Record 47 of Set 25 | geraldton
# Processing Record 48 of Set 25 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 25 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 25 | hobyo
# Processing Record 1 of Set 26 | te anau
# Processing Record 2 of Set 26 | hengshui
# Processing Record 3 of Set 26 | kamaishi
# Processing Record 4 of Set 26 | aswan
# Processing Record 5 of Set 26 | santa ines
# Processing Record 6 of Set 26 | novobataysk
# Processing Record 7 of Set 26 | krasnozavodsk
# Processing Record 8 of Set 26 | bayan
# Processing Record 9 of Set 26 | avera
# Processing Record 10 of Set 26 | hornepayne
# Processing Record 11 of Set 26 | coahuayana
# Processing Record 12 of Set 26 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 26 | tura
# Processing Record 14 of Set 26 | puerto penasco
# Processing Record 15 of Set 26 | yambio
# Processing Record 16 of Set 26 | vieques
# Processing Record 17 of Set 26 | kathmandu
# Processing Record 18 of Set 26 | omboue
# Processing Record 19 of Set 26 | senmonorom
# City not found. Skipping...
# Processing Record 20 of Set 26 | boyolangu
# Processing Record 21 of Set 26 | mikkeli
# Processing Record 22 of Set 26 | tomatlan
# Processing Record 23 of Set 26 | saint-francois
# Processing Record 24 of Set 26 | puerto carreno
# Processing Record 25 of Set 26 | salmo
# Processing Record 26 of Set 26 | bend
# Processing Record 27 of Set 26 | soe
# Processing Record 28 of Set 26 | cap malheureux
# Processing Record 29 of Set 26 | dalnerechensk
# Processing Record 30 of Set 26 | horsham
# Processing Record 31 of Set 26 | fairbanks
# Processing Record 32 of Set 26 | shache
# Processing Record 33 of Set 26 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 26 | plast
# Processing Record 35 of Set 26 | mangrol
# Processing Record 36 of Set 26 | orleans
# Processing Record 37 of Set 26 | samarai
# Processing Record 38 of Set 26 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 26 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 26 | sencha
# Processing Record 41 of Set 26 | sur
# Processing Record 42 of Set 26 | yemelyanovo
# Processing Record 43 of Set 26 | shenjiamen
# Processing Record 44 of Set 26 | sao joaquim
# Processing Record 45 of Set 26 | chumikan
# Processing Record 46 of Set 26 | vredendal
# Processing Record 47 of Set 26 | vydrino
# Processing Record 48 of Set 26 | hambantota
# Processing Record 49 of Set 26 | boa viagem
# Processing Record 50 of Set 26 | natitingou
# Processing Record 1 of Set 27 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 27 | holalkere
# Processing Record 3 of Set 27 | tsiroanomandidy
# Processing Record 4 of Set 27 | north bend
# Processing Record 5 of Set 27 | valentin gomez farias
# Processing Record 6 of Set 27 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 27 | el estor
# Processing Record 8 of Set 27 | balangiga
# Processing Record 9 of Set 27 | nanakuli
# Processing Record 10 of Set 27 | port-gentil
# Processing Record 11 of Set 27 | turukhansk
# Processing Record 12 of Set 27 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 27 | gorontalo
# Processing Record 14 of Set 27 | brookhaven
# Processing Record 15 of Set 27 | iskateley
# Processing Record 16 of Set 27 | margate
# Processing Record 17 of Set 27 | am timan
# Processing Record 18 of Set 27 | safaga
# Processing Record 19 of Set 27 | alta floresta
# Processing Record 20 of Set 27 | san vicente
# Processing Record 21 of Set 27 | nyurba
# Processing Record 22 of Set 27 | pangnirtung
# Processing Record 23 of Set 27 | urumqi
# Processing Record 24 of Set 27 | sterling
# Processing Record 25 of Set 27 | poum
# Processing Record 26 of Set 27 | boende
# Processing Record 27 of Set 27 | abnub
# Processing Record 28 of Set 27 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 27 | burica
# City not found. Skipping...
# Processing Record 30 of Set 27 | dali
# Processing Record 31 of Set 27 | blyth
# Processing Record 32 of Set 27 | sabang
# Processing Record 33 of Set 27 | vanavara
# Processing Record 34 of Set 27 | henties bay
# Processing Record 35 of Set 27 | bumba
# Processing Record 36 of Set 27 | orocue
# Processing Record 37 of Set 27 | krasnaya polyana
# Processing Record 38 of Set 27 | saint cyrus
# City not found. Skipping...
# Processing Record 39 of Set 27 | alyangula
# Processing Record 40 of Set 27 | nitra
# Processing Record 41 of Set 27 | cururupu
# Processing Record 42 of Set 27 | bang saphan
# Processing Record 43 of Set 27 | bandon
# Processing Record 44 of Set 27 | roma
# Processing Record 45 of Set 27 | adwa
# Processing Record 46 of Set 27 | altay
# Processing Record 47 of Set 27 | zverinogolovskoye
# Processing Record 48 of Set 27 | adrar
# Processing Record 49 of Set 27 | pontes e lacerda
# Processing Record 50 of Set 27 | bud
# Processing Record 1 of Set 28 | boddam
# Processing Record 2 of Set 28 | makinsk
# Processing Record 3 of Set 28 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 28 | tezu
# Processing Record 5 of Set 28 | bone
# Processing Record 6 of Set 28 | pyapon
# Processing Record 7 of Set 28 | mezen
# Processing Record 8 of Set 28 | seoul
# Processing Record 9 of Set 28 | macusani
# Processing Record 10 of Set 28 | bahia blanca
# Processing Record 11 of Set 28 | astana
# Processing Record 12 of Set 28 | gizo
# Processing Record 13 of Set 28 | anadyr
# Processing Record 14 of Set 28 | port moresby
# Processing Record 15 of Set 28 | pousat
# City not found. Skipping...
# Processing Record 16 of Set 28 | muscat
# Processing Record 17 of Set 28 | sao joao da barra
# Processing Record 18 of Set 28 | bourne
# Processing Record 19 of Set 28 | todos santos
# Processing Record 20 of Set 28 | launceston
# Processing Record 21 of Set 28 | qixingtai
# Processing Record 22 of Set 28 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 28 | beringovskiy
# Processing Record 24 of Set 28 | odweyne
# Processing Record 25 of Set 28 | matay
# Processing Record 26 of Set 28 | abu samrah
# Processing Record 27 of Set 28 | puerto quijarro
# Processing Record 28 of Set 28 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 28 | teeli
# Processing Record 30 of Set 28 | kathu
# Processing Record 31 of Set 28 | vanderhoof
# Processing Record 32 of Set 28 | amot
# Processing Record 33 of Set 28 | batemans bay
# Processing Record 34 of Set 28 | kysyl-syr
# Processing Record 35 of Set 28 | antsohihy
# Processing Record 36 of Set 28 | nabire
# Processing Record 37 of Set 28 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 28 | banyo
# Processing Record 39 of Set 28 | tacoronte
# Processing Record 40 of Set 28 | sioux lookout
# Processing Record 41 of Set 28 | tarakan
# Processing Record 42 of Set 28 | pokhara
# Processing Record 43 of Set 28 | abakaliki
# Processing Record 44 of Set 28 | tilichiki
# Processing Record 45 of Set 28 | daru
# Processing Record 46 of Set 28 | severobaykalsk
# Processing Record 47 of Set 28 | samsun
# Processing Record 48 of Set 28 | sisimiut
# Processing Record 49 of Set 28 | itapuranga
# Processing Record 50 of Set 28 | mabaruma
# Processing Record 1 of Set 29 | cheremukhovo
# Processing Record 2 of Set 29 | toamasina
# Processing Record 3 of Set 29 | quatre cocos
# Processing Record 4 of Set 29 | cardston
# Processing Record 5 of Set 29 | domoni
# Processing Record 6 of Set 29 | takoradi
# Processing Record 7 of Set 29 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 29 | bambanglipuro
# Processing Record 9 of Set 29 | andenes
# Processing Record 10 of Set 29 | grabovo
# Processing Record 11 of Set 29 | kukshi
# Processing Record 12 of Set 29 | svetlaya
# Processing Record 13 of Set 29 | beyneu
# Processing Record 14 of Set 29 | karaidel
# Processing Record 15 of Set 29 | isiro
# Processing Record 16 of Set 29 | mayskiy
# Processing Record 17 of Set 29 | harrison
# Processing Record 18 of Set 29 | narodychi
# Processing Record 19 of Set 29 | poya
# Processing Record 20 of Set 29 | mazyr
# Processing Record 21 of Set 29 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 22 of Set 29 | itarema
# Processing Record 23 of Set 29 | passi
# Processing Record 24 of Set 29 | christchurch
# Processing Record 25 of Set 29 | san ignacio
# Processing Record 26 of Set 29 | weatherford
# Processing Record 27 of Set 29 | mut
# Processing Record 28 of Set 29 | soddy-daisy
# Processing Record 29 of Set 29 | awbari
# Processing Record 30 of Set 29 | zlatoustovsk
# City not found. Skipping...
# Processing Record 31 of Set 29 | tapiramuta
# Processing Record 32 of Set 29 | deputatskiy
# Processing Record 33 of Set 29 | richards bay
# Processing Record 34 of Set 29 | waipawa
# Processing Record 35 of Set 29 | hesla
# Processing Record 36 of Set 29 | noumea
# Processing Record 37 of Set 29 | san carlos
# Processing Record 38 of Set 29 | sindor
# Processing Record 39 of Set 29 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 29 | lakhisarai
# Processing Record 41 of Set 29 | skelleftea
# Processing Record 42 of Set 29 | freeport
# Processing Record 43 of Set 29 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 29 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 29 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 29 | korem
# Processing Record 47 of Set 29 | yurimaguas
# Processing Record 48 of Set 29 | traverse city
# Processing Record 49 of Set 29 | ambodifototra
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print("The number of cities returned from the data retrieval is", len(city_data))
# Out:
# The number of cities returned from the data retrieval is 692

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Hobart -42.8794  147.3294     73.06        47           0        1.99
# 1  Nanortalik  60.1432  -45.2371      9.14        61         100       13.76
# 2   Cape Town -33.9258   18.4232     70.12        70           0        1.01
# 3  Champerico  14.3000  -91.9167     81.36        64          27        1.23
# 4     Inirida   3.8653  -67.9239     74.14        94          79        1.83
# 5  Villarrica -25.7500  -56.4333     70.74        98         100        3.74
# 6       Oyama  36.3000  139.8000     45.61        26          28       10.11
# 7      Torbay  47.6666  -52.7314     45.75        94         100       18.41
# 8   Jamestown  42.0970  -79.2353     12.33        72           0        0.00
# 9    Badarwas  24.9667   77.5667     49.98        59           0        5.53
#
#   Country Current Description
# 0      AU           clear sky
# 1      GL     overcast clouds
# 2      ZA           clear sky
# 3      GT    scattered clouds
# 4      CO       broken clouds
# 5      PY     overcast clouds
# 6      JP    scattered clouds
# 7      CA       moderate rain
# 8      US           clear sky
# 9      IN           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hobart      AU -42.8794  147.3294     73.06        47           0
# 1       Nanortalik      GL  60.1432  -45.2371      9.14        61         100
# 2        Cape Town      ZA -33.9258   18.4232     70.12        70           0
# 3       Champerico      GT  14.3000  -91.9167     81.36        64          27
# 4          Inirida      CO   3.8653  -67.9239     74.14        94          79
# ..             ...     ...      ...       ...       ...       ...         ...
# 687     Skelleftea      SE  64.7507   20.9528     12.56        68          18
# 688       Freeport      US  40.6576  -73.5832     24.03        63           6
# 689          Korem      ET  12.5058   39.5228     49.75        80          13
# 690     Yurimaguas      PE  -5.9000  -76.0833     80.26        69          99
# 691  Traverse City      US  44.7631  -85.6206     23.74        75         100
#
#      Wind Speed Current Description
# 0          1.99           clear sky
# 1         13.76     overcast clouds
# 2          1.01           clear sky
# 3          1.23    scattered clouds
# 4          1.83       broken clouds
# ..          ...                 ...
# 687        1.14          few clouds
# 688        4.00           clear sky
# 689        1.81          few clouds
# 690        1.70          light rain
# 691        4.00     overcast clouds
#
# [692 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
